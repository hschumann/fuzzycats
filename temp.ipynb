# 4988  130116213     7/12/2013     7/12/2013             40        1
# 4989  130116214     7/12/2013     7/12/2013             40        1
# 4990  130116215     7/11/2013     7/11/2013           1750        1
# 4991  130323518     11/4/2013     11/1/2013           1700        3
# 4992  130116216     7/11/2013     7/11/2013           1430        1
# 4993  130116218     7/11/2013     7/11/2013           2030        1
# 4994  130116219     7/12/2013     7/11/2013           2100        1
# 4995  130116220     7/11/2013     7/11/2013           1830        1
# 4996  130116222     7/11/2013     7/11/2013           1945        1
# 4997  130116223     7/11/2013     7/11/2013           2000        1
# 4998  130116231     7/12/2013     7/12/2013            135        1
# 4999  130116233     7/11/2013      7/3/2013           1200        1
#
#         Area Name  Reporting District  Crime Code  \
# 0     77th Street                1241         626
# 1         Olympic                2071         510
# 2       Southeast                1823         510
# 3       Southeast                1803         510
# 4         Topanga                2133         745
# 5         Central                 111         110
# 6       Northeast                1125         510
# 7        Foothill                1641         510
# 8         Mission                1902         510
# 9        Van Nuys                 904         668
# 10        Mission                1964         510
# 11         Newton                1321         510
# 12    77th Street                1266         440
# 13    77th Street                1268         763
# 14    N Hollywood                1511         442
# 15      Southeast                1823         626
# 16        Central                 174         624
# 17        Central                 134         626
# 18        Central                 185         624
# 19        Central                 162         670
# 20        Central                 171         626
# 21        Central                 192         649
# 22        Central                 156         626
# 23        Central                 133         624
# 24        Central                 166         624
# 25        Central                 192         626
# 26    West Valley                1018         510
# 27        Central                 119         480
# 28        Central                 105         210
# 29        Central                 144         626
# ...           ...                 ...         ...
# 4970      Central                 157         624
# 4971      Central                 143         740
# 4972      Central                 138         626
# 4973      Central                 157         330
# 4974      Central                 161         624
# 4975      Central                 185         649
# 4976      Central                 195         310
# 4977      Central                 128         440
# 4978      Central                 158         745
# 4979      Central                 166         210
# 4980      Central                 122         354
# 4981      Central                 139         480
# 4982      Central                 152         668
# 4983      Central                 152         745
# 4984      Central                 105         510
# 4985      Central                 111         624
# 4986      Central                 142         440
# 4987      Central                 148         351
# 4988      Central                 164         624
# 4989      Central                 164         624
# 4990      Central                 176         625
# 4991    Southwest                 301         510
# 4992      Central                 152         480
# 4993      Central                 111         624
# 4994      Central                 161         442
# 4995      Central                 147         210
# 4996      Central                 162         624
# 4997      Central                 163         664
# 4998      Central                 134         930
# 4999      Central                 161         354
#
#                                  Crime Code Description  \
# 0                     INTIMATE PARTNER - SIMPLE ASSAULT
# 1                                      VEHICLE - STOLEN
# 2                                      VEHICLE - STOLEN
# 3                                      VEHICLE - STOLEN
# 4              VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 5                                     CRIMINAL HOMICIDE
# 6                                      VEHICLE - STOLEN
# 7                                      VEHICLE - STOLEN
# 8                                      VEHICLE - STOLEN
# 9            EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)
# 10                                     VEHICLE - STOLEN
# 11                                     VEHICLE - STOLEN
# 12                   THEFT PLAIN - PETTY ($950 & UNDER)
# 13                                             STALKING
# 14             SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 15                    INTIMATE PARTNER - SIMPLE ASSAULT
# 16                             BATTERY - SIMPLE ASSAULT
# 17                    INTIMATE PARTNER - SIMPLE ASSAULT
# 18                             BATTERY - SIMPLE ASSAULT
# 19             EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)
# 20                    INTIMATE PARTNER - SIMPLE ASSAULT
# 21                     DOCUMENT FORGERY / STOLEN FELONY
# 22                    INTIMATE PARTNER - SIMPLE ASSAULT
# 23                             BATTERY - SIMPLE ASSAULT
# 24                             BATTERY - SIMPLE ASSAULT
# 25                    INTIMATE PARTNER - SIMPLE ASSAULT
# 26                                     VEHICLE - STOLEN
# 27                                        BIKE - STOLEN
# 28                                              ROBBERY
# 29                    INTIMATE PARTNER - SIMPLE ASSAULT
# ...                                                 ...
# 4970                           BATTERY - SIMPLE ASSAULT
# 4971  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 4972                  INTIMATE PARTNER - SIMPLE ASSAULT
# 4973                              BURGLARY FROM VEHICLE
# 4974                           BATTERY - SIMPLE ASSAULT
# 4975                   DOCUMENT FORGERY / STOLEN FELONY
# 4976                                           BURGLARY
# 4977                 THEFT PLAIN - PETTY ($950 & UNDER)
# 4978           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4979                                            ROBBERY
# 4980                                  THEFT OF IDENTITY
# 4981                                      BIKE - STOLEN
# 4982         EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)
# 4983           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4984                                   VEHICLE - STOLEN
# 4985                           BATTERY - SIMPLE ASSAULT
# 4986                 THEFT PLAIN - PETTY ($950 & UNDER)
# 4987                                    PURSE SNATCHING
# 4988                           BATTERY - SIMPLE ASSAULT
# 4989                           BATTERY - SIMPLE ASSAULT
# 4990                                      OTHER ASSAULT
# 4991                                   VEHICLE - STOLEN
# 4992                                      BIKE - STOLEN
# 4993                           BATTERY - SIMPLE ASSAULT
# 4994           SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 4995                                            ROBBERY
# 4996                           BATTERY - SIMPLE ASSAULT
# 4997                                 BUNCO, PETTY THEFT
# 4998             CRIMINAL THREATS - NO WEAPON DISPLAYED
# 4999                                  THEFT OF IDENTITY
#
#                                 MO Codes    ...      Status Description  \
# 0                    0416 0446 1243 2000    ...             Adult Other
# 1                                    NaN    ...             Invest Cont
# 2                                    NaN    ...             Invest Cont
# 3                                    NaN    ...             Invest Cont
# 4                                    329    ...             Invest Cont
# 5     1243 2000 1813 1814 2002 0416 0400    ...            Adult Arrest
# 6                                    NaN    ...             Invest Cont
# 7                                    NaN    ...             Invest Cont
# 8                                    NaN    ...             Invest Cont
# 9                              0344 1300    ...             Invest Cont
# 10                                   NaN    ...             Invest Cont
# 11                                   NaN    ...             Invest Cont
# 12                        1300 0701 1402    ...             Invest Cont
# 13                        0443 0913 1309    ...             Adult Other
# 14                             1402 0325    ...             Invest Cont
# 15                   0334 0443 0408 0416    ...             Invest Cont
# 16                        0416 0400 0429    ...             Invest Cont
# 17    2004 1218 1813 1814 2002 0444 2000    ...             Invest Cont
# 18                   0917 0419 0429 0417    ...              Juv Arrest
# 19                                   344    ...             Invest Cont
# 20                             2000 0416    ...             Invest Cont
# 21                                   800    ...             Invest Cont
# 22                   0305 0400 0429 2000    ...             Adult Other
# 23                                   400    ...             Invest Cont
# 24                             0400 2000    ...             Invest Cont
# 25                             2000 0416    ...             Invest Cont
# 26                                   NaN    ...             Invest Cont
# 27                                   344    ...            Adult Arrest
# 28              1218 1310 0344 0400 0352    ...             Invest Cont
# 29                        0400 2000 0429    ...             Invest Cont
# ...                                  ...    ...                     ...
# 4970                           0429 0416    ...             Invest Cont
# 4971                      0329 1803 1402    ...            Adult Arrest
# 4972                 2000 1402 0416 1813    ...             Invest Cont
# 4973                      1609 1307 0344    ...             Invest Cont
# 4974                 0344 1402 1602 0416    ...            Adult Arrest
# 4975                      0325 0344 1236    ...             Invest Cont
# 4976                      1607 1609 0344    ...             Invest Cont
# 4977                                 344    ...             Invest Cont
# 4978                                 329    ...             Invest Cont
# 4979                 0344 0906 0346 0370    ...             Adult Other
# 4980                           0922 1822    ...             Invest Cont
# 4981                                 344    ...             Invest Cont
# 4982                                1501    ...             Invest Cont
# 4983                                 329    ...             Invest Cont
# 4984                                 NaN    ...             Invest Cont
# 4985                      0913 0416 0444    ...             Adult Other
# 4986                                 344    ...             Invest Cont
# 4987       0305 0444 0390 0344 0429 0346    ...             Invest Cont
# 4988                                 444    ...             Invest Cont
# 4989                                 416    ...             Invest Cont
# 4990                 0356 1218 0319 0443    ...             Invest Cont
# 4991                                 NaN    ...             Invest Cont
# 4992                                 344    ...             Invest Cont
# 4993                      0416 0417 0429    ...             Invest Cont
# 4994                                 325    ...             Invest Cont
# 4995                 2004 0355 0305 0449    ...            Adult Arrest
# 4996                      1402 0416 2004    ...             Invest Cont
# 4997                      0800 0344 0346    ...             Invest Cont
# 4998                      0319 0443 2126    ...             Invest Cont
# 4999                      0100 0928 0930    ...             Invest Cont
#
#      Crime Code 1 Crime Code 2  Crime Code 3 Crime Code 4  \
# 0             626          NaN           NaN          NaN
# 1             510          NaN           NaN          NaN
# 2             510          NaN           NaN          NaN
# 3             510          NaN           NaN          NaN
# 4             745          NaN           NaN          NaN
# 5             110          NaN           NaN          NaN
# 6             510          NaN           NaN          NaN
# 7             510          NaN           NaN          NaN
# 8             510          NaN           NaN          NaN
# 9             668          NaN           NaN          NaN
# 10            510          NaN           NaN          NaN
# 11            510          NaN           NaN          NaN
# 12            440        998.0           NaN          NaN
# 13            763          NaN           NaN          NaN
# 14            442        998.0           NaN          NaN
# 15            626          NaN           NaN          NaN
# 16            624          NaN           NaN          NaN
# 17            626          NaN           NaN          NaN
# 18            624          NaN           NaN          NaN
# 19            670          NaN           NaN          NaN
# 20            626          NaN           NaN          NaN
# 21            649          NaN           NaN          NaN
# 22            626          NaN           NaN          NaN
# 23            624          NaN           NaN          NaN
# 24            624        999.0           NaN          NaN
# 25            626          NaN           NaN          NaN
# 26            510          NaN           NaN          NaN
# 27            480          NaN           NaN          NaN
# 28            210          NaN           NaN          NaN
# 29            626          NaN           NaN          NaN
# ...           ...          ...           ...          ...
# 4970          624          NaN           NaN          NaN
# 4971          740        998.0           NaN          NaN
# 4972          626        998.0           NaN          NaN
# 4973          330          NaN           NaN          NaN
# 4974          624        998.0           NaN          NaN
# 4975          649          NaN           NaN          NaN
# 4976          310          NaN           NaN          NaN
# 4977          440          NaN           NaN          NaN
# 4978          745          NaN           NaN          NaN
# 4979          210          NaN           NaN          NaN
# 4980          354          NaN           NaN          NaN
# 4981          480          NaN           NaN          NaN
# 4982          668          NaN           NaN          NaN
# 4983          745          NaN           NaN          NaN
# 4984          510          NaN           NaN          NaN
# 4985          624          NaN           NaN          NaN
# 4986          440          NaN           NaN          NaN
# 4987          351          NaN           NaN          NaN
# 4988          624          NaN           NaN          NaN
# 4989          624          NaN           NaN          NaN
# 4990          625          NaN           NaN          NaN
# 4991          510          NaN           NaN          NaN
# 4992          480          NaN           NaN          NaN
# 4993          624          NaN           NaN          NaN
# 4994          442          NaN           NaN          NaN
# 4995          210          NaN           NaN          NaN
# 4996          624          NaN           NaN          NaN
# 4997          664          NaN           NaN          NaN
# 4998          930          NaN           NaN          NaN
# 4999          354          NaN           NaN          NaN
#
#                                        Address  \
# 0      6300    BRYNHURST                    AV
# 1                                     VAN NESS
# 2       200 E  104TH                        ST
# 3                                         88TH
# 4      7200    CIRRUS                       WY
# 5       600 N  HILL                         ST
# 6                                         YORK
# 7                                    EL DORADO
# 8                                     GLENOAKS
# 9      7200    SEPULVEDA                    BL
# 10                                    NORDHOFF
# 11                                        21ST
# 12                                        82ND
# 13      100 W  82ND                         ST
# 14    13000    SHERMAN                      WY
# 15             CENTURY                      BL
# 16      800 S  SPRING                       ST
# 17                                         4TH
# 18      300 E  PICO                         BL
# 19      700 W  7TH                          ST
# 20      800 W  OLYMPIC                      BL
# 21     1300 S  FIGUEROA                     ST
# 22             6TH                          ST
# 23      200 S  SPRING                       ST
# 24      600    WALL                         ST
# 25     1300 S  HOPE                         ST
# 26                                     ARMINTA
# 27      900 N  ALAMEDA                      ST
# 28                                     BISHOPS
# 29      400 S  MAIN                         ST
# ...                                        ...
# 4970    500 S  SAN PEDRO                    ST
# 4971    400 S  HILL                         ST
# 4972           3RD                          ST
# 4973                                       6TH
# 4974    700 S  FIGUEROA                     ST
# 4975    100 E  12TH                         ST
# 4976    200 E  WASHINGTON                   BL
# 4977    100 S  CENTRAL                      AV
# 4978    400 S  CENTRAL                      AV
# 4979           6TH                          ST
# 4980    100 N  HILL                         ST
# 4981    800 E  3RD                          ST
# 4982    500 S  OLIVE                        ST
# 4983    400 W  7TH                          ST
# 4984                                  CASANOVA
# 4985    800    NEW DEPOT                    ST
# 4986    300 S  GRAND                        AV
# 4987           5TH                          ST
# 4988                                       6TH
# 4989                                       6TH
# 4990           8TH                          ST
# 4991                                     CLYDE
# 4992           6TH                          ST
# 4993    600 N  FIGUEROA                     ST
# 4994    700 S  FIGUEROA                     ST
# 4995    300    WINSTON                      ST
# 4996    700 S  OLIVE                        ST
# 4997           7TH                          ST
# 4998    300 W  3RD                          ST
# 4991                            ADAMS  (34.0325, -118.3669)  34.0325
# 4992                           FLOWER  (34.0502, -118.2574)  34.0502
# 4993                              NaN  (34.0627, -118.2463)  34.0627
# 4994                              NaN  (34.0494, -118.2599)  34.0494
# 4995                              NaN  (34.0455, -118.2452)  34.0455
# 4996                              NaN  (34.0467, -118.2556)  34.0467
# 4997                             HILL  (34.0459, -118.2545)  34.0459
# 4998                              NaN    (34.051, -118.248)  34.0510
# 4999                              NaN  (34.0494, -118.2599)  34.0494
#
#       longitude
# 0     -118.3338
# 1     -118.3157
# 2     -118.2717
# 3     -118.2717
# 4     -118.6369
# 5     -118.2412
# 6     -118.2048
# 7     -118.3987
# 8     -118.4589
# 9     -118.4662
# 10    -118.4517
# 11    -118.2671
# 12    -118.2783
# 13    -118.2754
# 14    -118.4160
# 15    -118.2652
# 16    -118.2536
# 17    -118.2504
# 18    -118.2583
# 19    -118.2577
# 20    -118.2640
# 21    -118.2680
# 22    -118.2452
# 23    -118.2456
# 24    -118.2471
# 25    -118.2656
# 26    -118.4793
# 27    -118.2371
# 28    -118.2333
# 29    -118.2472
# ...         ...
# 4970  -118.2439
# 4971  -118.2504
# 4972  -118.2411
# 4973  -118.2436
# 4974  -118.2599
# 4975  -118.2594
# 4976  -118.2635
# 4977  -118.2391
# 4978  -118.2397
# 4979  -118.2452
# 4980  -118.2466
# 4981  -118.2364
# 4982  -118.2529
# 4983  -118.2545
# 4984  -118.2291
# 4985  -118.2431
# 4986  -118.2513
# 4987  -118.2420
# 4988  -118.2509
# 4989  -118.2509
# 4990  -118.2496
# 4991  -118.3669
# 4992  -118.2574
# 4993  -118.2463
# 4994  -118.2599
# 4995  -118.2452
# 4996  -118.2556
# 4997  -118.2545
# 4998  -118.2480
# 4999  -118.2599
#
# [5000 rows x 28 columns]

# %%
## rescale time variable
def newTimes(df):
    df['Time Occurred'][np.where(df['Time Occurred'] < 800)[0]] = 2400 - (800 - df['Time Occurred'][np.where(df['Time Occurred'] < 800)[0]])
    df['Time Occurred'][np.where(df['Time Occurred'] >= 800)[0]] = df['Time Occurred'][np.where(df['Time Occurred'] >= 800)[0]] - 800
    
## make sex binary!
def newSex(df):
    df['Sex'] = np.zeros(len(df['Victim Sex']))
    df['Sex'][np.where(df['Victim Sex'] == 'M')[0]] = 1
    df['Sex'][np.where(df['Victim Sex'] == 'F')[0]] = 0
    df['Sex'][np.where(df['Victim Sex'] == '')[0]] = 0

## clean age (remove missing values)
def cleanAge(df):
    meanAge = np.mean(df['Victim Age'])
    df['Victim Age'][np.isnan(df['Victim Age'])] = meanAge

## Normilze All Variables
def normalizeDF(df,columns):
    return (df[columns] - df[columns].mean()) / (np.absolute(df[columns]).max())

# %%
## distance formulas
def L2Norm(pt1,pt2):
    return np.sqrt(np.sum((pt1.values[0] - pt2.values[0]) ** 2))

def L1Norm(pt1,pt2):
    return np.sum(np.absolute((pt1.values[0] - pt2.values[0])))

# %%
def classifyPoint(point, centroids, clusters, distFunc):
    smallestDist = np.inf
    closestCentroid = 0
    
    for c in range(len(centroids)):
        #if (centroids.iloc[[c]].equals(point)):
        #    closestCentroid = c
        
        temp = distFunc(centroids.iloc[[c]], point)
        if temp < smallestDist:
            closestCentroid = c
            smallestDist = temp
            
    # Add point to closest cluster
    clusters[closestCentroid].append(point)

# %%
def getCentroids(df, centroids, clusters):
    newClusters = pd.DataFrame(data=None, columns=df.columns)
    for key, points in clusters.items():
        if points == []:
            newClusters = pd.concat([newClusters, centroids.iloc[[key]]], axis=0)
        else:
            cluster = pd.DataFrame(data=None, columns=df.columns)
            for p in points:
                cluster = pd.concat([cluster, pd.DataFrame(p)], axis=0)
            newClusters = newClusters.append(np.mean(cluster), ignore_index=True)
    
    return newClusters

# %%
def cluster(df,columns,k):
    df = df[columns]
    
    ## pick k random points from the data set 
    ## and make sure they are unique
    firstIDs = np.random.randint(len(df), size = k)
    while (len(np.unique(firstIDs)) < k):
        firstIDs = np.random.randint(len(df), size = k)
    
    ## set centroids
    centroids = df.iloc[firstIDs]
    centroids.index = range(k)
    
    ## run until clusters don't change (hopefully not forever)
    while True:
        clusters = {k: [] for k in range(k)}
        for p in range(len(df)):
            point = df.iloc[[p]]
            classifyPoint(point, centroids, clusters, L2Norm)
            
        newCentroids = getCentroids(df, centroids, clusters)
        
        # maybe check if it hits a certain threshold?
        if (centroids.equals(newCentroids)):
            break
        else:
            centroids = newCentroids
            
    return clusters

# %%
crimeCodes = crime[['Crime Code', 'Crime Code Description']]
crimeCodes['Crime Code'] = (crimeCodes['Crime Code'] - crimeCodes['Crime Code'].mean()) / (np.absolute(crimeCodes['Crime Code']).max())
crimeCodesMap = {code: desc for code, desc in crimeCodes.itertuples(index=False)}
#crimeCodesMap
# Out:
# C:\Users\Robert\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
cols = ['Time Occurred','Area ID','Reporting District','Crime Code','Victim Age','Sex','Premise Code','latitude','longitude']

# %%
## data cleaning
newTimes(crime)
newSex(crime)
cleanAge(crime)
crime = normalizeDF(crime, cols)
# Out:
# C:\Users\Robert\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Robert\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Robert\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\Robert\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Robert\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Robert\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
clusters = cluster(crime,cols,3)

# %%
clusters.keys()

# %%
clusters.items()[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-93d96bf1b888> in <module>()
# ----> 1 clusters.items()[0]
#
# TypeError: 'dict_items' object does not support indexing

# %%
niceDisplay = pd.DataFrame(data=None, columns=cols)
for cluster, points in clusters.items():
    for point in points:
        temp = pd.DataFrame(point)
        temp['Cluster'] = cluster
        niceDisplay = niceDisplay.append(temp, ignore_index=True)

# %%
crimeCodes.head()
# Out:
#    Crime Code                    Crime Code Description
# 0    0.107352         INTIMATE PARTNER - SIMPLE ASSAULT
# 1   -0.013987                          VEHICLE - STOLEN
# 2   -0.013987                          VEHICLE - STOLEN
# 3   -0.013987                          VEHICLE - STOLEN
# 4    0.231829  VANDALISM - MISDEAMEANOR ($399 OR UNDER)

# %%
niceDisplay.head()
# Out:
#     Area ID  Cluster  Crime Code  Premise Code  Reporting District     Sex  \
# 0  0.371410      0.0   -0.087209     -0.176571            0.360983  0.5086
# 1  0.371410      0.0    0.250658     -0.185203            0.361893  0.5086
# 2  0.514267      0.0   -0.085117      0.188410            0.472448  0.5086
# 3 -0.152400      0.0    0.105260     -0.183970           -0.135833  0.5086
# 4 -0.152400      0.0    0.153377      0.188410           -0.141292  0.5086
#
#    Time Occurred  Victim Age  latitude  longitude
# 0      -0.306978    0.045669 -0.002706  -0.000006
# 1      -0.306978   -0.085644 -0.002706   0.000018
# 2       0.225415   -0.257361  0.004162  -0.001167
# 3      -0.165862   -0.146250 -0.000437   0.000202
# 4       0.032984   -0.126048 -0.000294   0.000167

# %%
niceDisplay1 = pd.merge_asof(niceDisplay.sort_values(by=["Crime Code"]), crimeCodes., on=['Crime Code'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-14fa8346d6e4> in <module>()
# ----> 1 niceDisplay1 = pd.merge_asof(niceDisplay, crimeCodes, on=['Crime Code'])
#
# C:\Users\Robert\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge_asof(left, right, on, left_on, right_on, left_index, right_index, by, left_by, right_by, suffixes, tolerance, allow_exact_matches, direction)
#     484                     allow_exact_matches=allow_exact_matches,
#     485                     direction=direction)
# --> 486     return op.get_result()
#     487
#     488
#
# C:\Users\Robert\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#    1017
#    1018     def get_result(self):
# -> 1019         join_index, left_indexer, right_indexer = self._get_join_info()
#    1020
#    1021         # this is a bit kludgy
#
# C:\Users\Robert\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
#     732         else:
#     733             (left_indexer,
# --> 734              right_indexer) = self._get_join_indexers()
#     735
#     736             if self.right_index:
#
# C:\Users\Robert\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(self)
#    1241         msg = " keys must be sorted"
#    1242         if not Index(left_values).is_monotonic:
# -> 1243             raise ValueError('left' + msg)
#    1244         if not Index(right_values).is_monotonic:
#    1245             raise ValueError('right' + msg)
#
# ValueError: left keys must be sorted

# %%
niceDisplay1.shape

# %% [markdown]
# # Clustered Data

# %%
#niceDisplay
niceDisplay.set_index('Cluster')
# Out:
#           Area ID  Crime Code  Premise Code  Reporting District     Sex  \
# Cluster
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# 0.0      0.371410   -0.087209     -0.176571            0.360983  0.5086
# ...           ...         ...           ...                 ...     ...
# 2.0      0.704743    0.130365     -0.059432            0.692193  0.5086
# 2.0      0.704743    0.130365     -0.059432            0.692193  0.5086
# 2.0      0.704743    0.130365     -0.059432            0.692193  0.5086
# 2.0      0.704743    0.130365     -0.059432            0.692193  0.5086
# 2.0      0.704743    0.130365     -0.059432            0.692193  0.5086
# 2.0      0.704743    0.130365      0.308016            0.660346  0.5086
# 2.0      0.704743    0.130365      0.308016            0.660346  0.5086
# 2.0      0.704743    0.130365      0.308016            0.660346  0.5086
# 2.0      0.704743    0.130365      0.308016            0.660346  0.5086
# 2.0      0.704743    0.130365      0.308016            0.660346  0.5086
# 2.0      0.704743    0.130365      0.308016            0.660346  0.5086
# 2.0      0.799981    0.130365     -0.185203            0.755432  0.5086
# 2.0      0.799981    0.130365     -0.185203            0.755432  0.5086
# 2.0      0.799981    0.130365     -0.185203            0.755432  0.5086
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# 0.0      THEFT PLAIN - PETTY ($950 & UNDER)
# ...                                     ...
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                   ARSON
# 2.0                                 PIMPING
#
# [2108692 rows x 10 columns]

# %% [markdown]
# # Displays Top 5 Crimes in Cluster 0

# %%
niceDisplay.loc[niceDisplay['Cluster'] == 0].groupby(['Crime Code Description']).count().sort_values(by=['Crime Code'], ascending=False).head()
# Out:
#                                           Area ID  Cluster  Crime Code  \
# Crime Code Description
# BATTERY - SIMPLE ASSAULT                   285520   285520      285520
# THEFT PLAIN - PETTY ($950 & UNDER)         119700   119700      119700
# BURGLARY FROM VEHICLE                       56917    56917       56917
# ROBBERY                                     32864    32864       32864
# VANDALISM - MISDEAMEANOR ($399 OR UNDER)    32560    32560       32560
#
#                                           Premise Code  Reporting District  \
# Crime Code Description
# BATTERY - SIMPLE ASSAULT                        285520              285520
# THEFT PLAIN - PETTY ($950 & UNDER)              119700              119700
# BURGLARY FROM VEHICLE                            56917               56917
# ROBBERY                                          32864               32864
# VANDALISM - MISDEAMEANOR ($399 OR UNDER)         32560               32560
#
#                                              Sex  Time Occurred  Victim Age  \
# Crime Code Description
# BATTERY - SIMPLE ASSAULT                  285520         285520      285520
# THEFT PLAIN - PETTY ($950 & UNDER)        119700         119700      119700
# BURGLARY FROM VEHICLE                      56917          56917       56917
# ROBBERY                                    32864          32864       32864
# VANDALISM - MISDEAMEANOR ($399 OR UNDER)   32560          32560       32560
#
#                                           latitude  longitude
# Crime Code Description
# BATTERY - SIMPLE ASSAULT                    285520     285520
# THEFT PLAIN - PETTY ($950 & UNDER)          119700     119700
# BURGLARY FROM VEHICLE                        56917      56917
# ROBBERY                                      32864      32864
# VANDALISM - MISDEAMEANOR ($399 OR UNDER)     32560      32560

# %%
niceDisplay.loc[niceDisplay['Cluster'] == 1].groupby(['Crime Code Description']).count().sort_values(by=['Crime Code'], ascending=False).head()
# Out:
#                                     Area ID  Cluster  Crime Code  \
# Crime Code Description
# BATTERY - SIMPLE ASSAULT             187136   187136      187136
# VEHICLE - STOLEN                     125736   125736      125736
# THEFT PLAIN - PETTY ($950 & UNDER)    80550    80550       80550
# BURGLARY FROM VEHICLE                 39151    39151       39151
# INTIMATE PARTNER - SIMPLE ASSAULT     23270    23270       23270
#
#                                     Premise Code  Reporting District     Sex  \
# Crime Code Description
# BATTERY - SIMPLE ASSAULT                  187136              187136  187136
# VEHICLE - STOLEN                          125736              125736  125736
# THEFT PLAIN - PETTY ($950 & UNDER)         80550               80550   80550
# BURGLARY FROM VEHICLE                      39151               39151   39151
# INTIMATE PARTNER - SIMPLE ASSAULT          23270               23270   23270
#
#                                     Time Occurred  Victim Age  latitude  \
# Crime Code Description
# BATTERY - SIMPLE ASSAULT                   187136      187136    187136
# VEHICLE - STOLEN                           125736      125736    125736
# THEFT PLAIN - PETTY ($950 & UNDER)          80550       80550     80550
# BURGLARY FROM VEHICLE                       39151       39151     39151
# INTIMATE PARTNER - SIMPLE ASSAULT           23270       23270     23270
#
#                                     longitude
# Crime Code Description
# BATTERY - SIMPLE ASSAULT               187136
# VEHICLE - STOLEN                       125736
# THEFT PLAIN - PETTY ($950 & UNDER)      80550
# BURGLARY FROM VEHICLE                   39151
# INTIMATE PARTNER - SIMPLE ASSAULT       23270

# %%
niceDisplay.loc[niceDisplay['Cluster'] == 2].groupby(['Crime Code Description']).count().sort_values(by=['Crime Code'], ascending=False).head()
# Out:
#                                     Area ID  Cluster  Crime Code  \
# Crime Code Description
# VEHICLE - STOLEN                     897390   897390      897390
# BURGLARY FROM VEHICLE                 12173    12173       12173
# BURGLARY                               3036     3036        3036
# THEFT PLAIN - PETTY ($950 & UNDER)     2250     2250        2250
# ROBBERY                                1248     1248        1248
#
#                                     Premise Code  Reporting District     Sex  \
# Crime Code Description
# VEHICLE - STOLEN                          897390              897390  897390
# BURGLARY FROM VEHICLE                      12173               12173   12173
# BURGLARY                                    3036                3036    3036
# THEFT PLAIN - PETTY ($950 & UNDER)          2250                2250    2250
# ROBBERY                                     1248                1248    1248
#
#                                     Time Occurred  Victim Age  latitude  \
# Crime Code Description
# VEHICLE - STOLEN                           897390      897390    897390
# BURGLARY FROM VEHICLE                       12173       12173     12173
# BURGLARY                                     3036        3036      3036
# THEFT PLAIN - PETTY ($950 & UNDER)           2250        2250      2250
# ROBBERY                                      1248        1248      1248
#
#                                     longitude
# Crime Code Description
# VEHICLE - STOLEN                       897390
# BURGLARY FROM VEHICLE                   12173
# BURGLARY                                 3036
# THEFT PLAIN - PETTY ($950 & UNDER)       2250
# ROBBERY                                  1248

# %%
## Was trying to see if there was a good way to chart some of this stuff for the presentation.
## Still thinking about it

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
niceDisplay.head()
# Out:
#    Area ID  Cluster  Crime Code  Premise Code  Reporting District     Sex  \
# 0  0.37141      0.0   -0.087209     -0.176571            0.360983  0.5086
# 1  0.37141      0.0   -0.087209     -0.176571            0.360983  0.5086
# 2  0.37141      0.0   -0.087209     -0.176571            0.360983  0.5086
# 3  0.37141      0.0   -0.087209     -0.176571            0.360983  0.5086
# 4  0.37141      0.0   -0.087209     -0.176571            0.360983  0.5086
#
#    Time Occurred  Victim Age  latitude  longitude  \
# 0      -0.306978    0.045669 -0.002706  -0.000006
# 1      -0.306978    0.045669 -0.002706  -0.000006
# 2      -0.306978    0.045669 -0.002706  -0.000006
# 3      -0.306978    0.045669 -0.002706  -0.000006
# 4      -0.306978    0.045669 -0.002706  -0.000006
#
#                Crime Code Description
# 0  THEFT PLAIN - PETTY ($950 & UNDER)
# 1  THEFT PLAIN - PETTY ($950 & UNDER)
# 2  THEFT PLAIN - PETTY ($950 & UNDER)
# 3  THEFT PLAIN - PETTY ($950 & UNDER)
# 4  THEFT PLAIN - PETTY ($950 & UNDER)

# %%
niceDisplay.loc[niceDisplay["Cluster"] == 0.0].groupby(["Cluster", "Crime Code Description"]).count()["Area ID"]
# Out:
# Cluster  Crime Code Description
# 0.0      ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER                            1
#          ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT                      23355
#          ATTEMPTED ROBBERY                                                     468
#          BATTERY - SIMPLE ASSAULT                                           285520
#          BATTERY POLICE (SIMPLE)                                               837
#          BATTERY WITH SEXUAL CONTACT                                            66
#          BEASTIALITY, CRIME AGAINST NATURE SEXUAL ASSLT WITH ANIM0065            1
#          BIKE - ATTEMPTED STOLEN                                                 1
#          BIKE - STOLEN                                                       10324
#          BOMB SCARE                                                             28
#          BRANDISH WEAPON                                                       980
#          BUNCO, ATTEMPT                                                          2
#          BUNCO, GRAND THEFT                                                     60
#          BUNCO, PETTY THEFT                                                    126
#          BURGLARY                                                            10626
#          BURGLARY FROM VEHICLE                                               56917
#          BURGLARY FROM VEHICLE, ATTEMPTED                                       20
#          BURGLARY, ATTEMPTED                                                    30
#          CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT                                16
#          CHILD ANNOYING (17YRS & UNDER)                                          3
#          CHILD NEGLECT (SEE 300 W.I.C.)                                         10
#          COUNTERFEIT                                                            15
#          CREDIT CARDS, FRAUD USE ($950.01 & OVER)                                1
#          CRIMINAL HOMICIDE                                                      24
#          CRIMINAL THREATS - NO WEAPON DISPLAYED                               9375
#          CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)0060            4
#          CRUELTY TO ANIMALS                                                      4
#          DEFRAUDING INNKEEPER/THEFT OF SERVICES, $400 & UNDER                  440
#          DISCHARGE FIREARMS/SHOTS FIRED                                          2
#          DISHONEST EMPLOYEE - PETTY THEFT                                        1
#                                                                              ...
#          PROWLER                                                                 1
#          PURSE SNATCHING                                                         7
#          RECKLESS DRIVING                                                        1
#          RESISTING ARREST                                                      240
#          ROBBERY                                                             32864
#          SEXUAL PENTRATION WITH A FOREIGN OBJECT                                 5
#          SHOPLIFTING - ATTEMPT                                                   1
#          SHOPLIFTING - PETTY THEFT ($950 & UNDER)                             6789
#          SHOPLIFTING-GRAND THEFT ($950.01 & OVER)                                2
#          SHOTS FIRED AT INHABITED DWELLING                                       3
#          SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH 0007=02        24
#          STALKING                                                                5
#          THEFT FROM MOTOR VEHICLE - GRAND ($400 AND OVER)                      984
#          THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)                      2856
#          THEFT OF IDENTITY                                                    4300
#          THEFT PLAIN - ATTEMPT                                                   4
#          THEFT PLAIN - PETTY ($950 & UNDER)                                 119700
#          THEFT, PERSON                                                        2508
#          THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD0036        15040
#          THREATENING PHONE CALLS/LETTERS                                         8
#          THROWING OBJECT AT MOVING VEHICLE                                      35
#          TRESPASSING                                                          3604
#          UNAUTHORIZED COMPUTER ACCESS                                           12
#          VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS) 0114        12288
#          VANDALISM - MISDEAMEANOR ($399 OR UNDER)                            32560
#          VEHICLE - ATTEMPT STOLEN                                               20
#          VEHICLE - STOLEN                                                     5070
#          VIOLATION OF COURT ORDER                                              208
#          VIOLATION OF RESTRAINING ORDER                                         85
#          WEAPONS POSSESSION/BOMBING                                              1
# Name: Area ID, Length: 79, dtype: int64

# %%
#cluster1 = niceDisplay[niceDisplay['Cluster'] == 0]
#cluster1

# %%
#cluster1.groupby('Crime Code').count()['Sex'].plot.bar()

# %%
#cluster1.set_index("Cluster")["Crime Code"].plot.bar()

# %%
#cluster1
